# %%
import skimage.io as io

# %%
import matplotlib.pyplot as plt

# %%
image2=io.imread('sdgs.png')

# %%
plt.imshow(image2)

# %%
image2.shape
# Out:
# (763, 1500, 3)

# %%
red=image2[:,:,0]
green=image2[:,:,1]
blue=image2[:,:,2]

# %%
plt.imshow(red,cmap="Reds")

# %%
plt.imshow(blue,cmap="Blues")

# %%
plt.imshow(blue,cmap="Greens")
